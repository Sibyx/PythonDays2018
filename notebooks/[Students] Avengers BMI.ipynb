# %% [markdown]
# # Uvod do Pandas
#
# ![image.png](attachment:image.png)
#
# Dokumentacia: [Pandas](https://pandas.pydata.org/pandas-docs/stable/)

# %% [markdown]
# ## Importovanie kniznice
#
# Predtym ako zacneme, potrebujeme importovat nasu kniznicu. Pouzijeme na to instrukciu `import`.

# %%
import pandas as pd

# %% [markdown]
# ## Nacitanie datoveho suboru
#
# Pandas nam uz ponuka vstavane funkcie na importovanie nasich datasetov.
#
# To bunky nizsie nacitame do premennej `df` subor `../data/avengers/bmi.csv` pomocou metody [pandas.read_csv()](http://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.read_csv.html).
#
# Pamataj ako sme importovali, Pandas kniznicu (pouzili sme alias `pd`).

# %%
# Sem vloz svoj kod

# %% [markdown]
# Vytvorili sme Pandas dataframe v premennej `df`. Pouzijeme na to nasledujuce funkcie:
# - [DataFrame.info()](http://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.info.html).
# - [DataFrame.head()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html)

# %%
# Tvoj kod

# %% [markdown]
# ## Normalizacia dat
#
# Teraz ked sa nam podarilo uspesne nacitat subor, vsimli sme si ze nejake veci sa nam tam nepacia.
#
# Napriklad sa mi nepaci hned prvy stlpec, ktory mi cisluje riadky. Pandas to uz robi za nas, cize je zbytocny. Chcem ho dat prec.
#
# Pouzijem na to metodu [df.iloc](https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.iloc.html), vystupom tejto operacie je novy dataframe, ktory vyhovuje podmienkam zadaneho indexovania. Vystupom prepisem moj aktualny dataframe, ktory uz nechcem.

# %%
df = df.iloc[:, 1:]

# %% [markdown]
# Dalej nemam v tabulke nazvy stlcov co nie je moc cool. Na pridanie vyplnime atribut [df.columns](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.columns.html#pandas.DataFrame.columns) v objekte `df`.
#
# Nase stlpce pomenujeme nasledovne:
# - Hero
# - Height
# - Weight

# %%
# Tvoj kod sem

# %% [markdown]
# Uz sa nam zacina rysovat celkom pekna tabulka. Skusme sa teraz pozriet trosku blizsie na hodnoty v tejto tabulke.
#
# Napriklad si mozeme vsimnut, ze namiesto neexistujucich hodnot mame v tabulke -1, co nam moze neskor poskodit statistiky. Preto sa pokusime toto cislo nahradit objektom typu `NaN (Not a Number)`. Tento typ hodnoty je velmi specificky a hovori Pandas, ze sa ma k datam tohoto typu spravat specialnejsie ako k ostatnym.
#
# Na odstranenie tejto hodnoty, pouzijeme metodu [df.repplace](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html).
#
# `df.replace` vracia opat novy dataframe.

# %%
# Tvoj kod sem

# %% [markdown]
# Nasej tabulke stale nieco chyba. Na pravej strane (1. stupec) chceme mat informaciu o tom, komu namerane hodnoty patria. Zatial tam mame iba cislo riadku. Meno hrdinu sa nachadza az v druhom stlpci. Pouzijeme metodu [df.set_index](http://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.set_index.html).

# %%
# Tvoj kod sem

# %% [markdown]
# ## Vypocet
#
# Nasa tabulka uz je upratana, podme teda pocitat BMI. Vytvorme si stlpec `BMI`.
#
# Najprv ho naplnume nulovou hodnotou a potom na zaklade dat v tabulke hodnotu vypocitame.

# %%
# Tvoj kod sem

# %% [markdown]
# ## Vizualizacia a analyza
#
# Uz mame vypocitane BMI. Teraz sa pokusime spravit nejaku zakladnu analyzu nad nasim datasetom.
#
# Zacneme tym, ze odstranime prazdne riadky z datasetu, tie momentalne nepotrebujeme.
#
# Pouzijeme na to metodu [df.dropna](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html).

# %%
# Tvoj kod sem

# %% [markdown]
# Teraz chcem vidiet, zoradit zaznamy v tabulke podla BMI.
# Pouzijem metody [df.sort_values](https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.sort_values.html).

# %%
# Tvoj kod sem

# %% [markdown]
# Teraz uz mame zoradene data, mozeme zacat klast otazky:
#
# - Kto ma nadvahu?
# - Kto ma normalnu hmotnost?
# - Kto je obezny?
# - Je obezny Gandalf?
#
# Odpovedz najdeme velmi jednoduchym sposobom, najprv potrebujeme vediet, ake hodnoty su priradene akej kategorii v BMI.
#
# ![Screen%20Shot%202018-05-29%20at%2023.15.58.png](attachment:Screen%20Shot%202018-05-29%20at%2023.15.58.png)
#
# Pouzijeme na filtrovanie tychto hodnot metodu [df.loc](https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.loc.html)

# %%
# Tvoj kod

# %% [markdown]
# Teraz uz mozeme vykreslit jednoduchy graf.

# %%
# Tvoj kod

# %% [markdown]
# # Generovanie dát

# %%
names = [
	"Iron Man",
	"Thor",
	"Ant-Man",
	"Wasp",
	"Hulk",
	"Captain America",
	"Hawkeye",
	"Quicksilver",
	"Scarlet Witch",
	"Swordsman",
	"Hercules",
	"Black Panther",
	"Vision",
	"Black Knight",
	"Black Widow",
	"Mantis",
	"Beast",
	"Moondragon",
	"Hellcat",
	"Two-Gun Kid",
	"Wonder Man",
	"Thing",
	"Human Torch",
	"Spider-Man",
	"Sandman",
	"Justice",
	"Wolverine",
	"Doctor Strange",
	"Daredevil",
    "Gandalf",
    "Sheldon Cooper"
]

data = {
	'Name': names
}

df = pd.DataFrame(columns=['Name', 'Height', 'Weight', 'BMI'], data=data)
df['Height'] = np.random.randint(low=160, high=220, size=(len(df.index),1)) / 100
df['Weight'] = np.random.randint(low=50, high=140, size=(len(df.index),1))

df.info()  # dataframe info

df

# df.to_csv("bmi.csv")
