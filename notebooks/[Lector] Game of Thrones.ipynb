# %% [markdown]
# # Game of Thrones
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Screentime analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/GoT/screentime/GoT_actors.csv')

df = df.set_index(['actor'])

df
# Out:
#                               season 1  season 2  season 3  season 4  \
# actor
# Xaro Xhoan Daxos                  0.00     10.50      0.00      0.00
# Tyrion Lannister                 52.75     65.00     50.00     47.75
# Margaery Tyrell                   0.00      9.50     21.25     17.75
# Ramsay Bolton                     0.00      0.00     12.75     13.50
# Joffrey Baratheon                17.75     17.50     20.25     14.75
# Osha                              8.00      9.50      8.75      0.00
# Janos Slynt                       1.00      4.25      0.00      5.25
# Renly Baratheon                   9.50     14.50      0.00      0.00
# Ros                               8.25     10.25      3.25      0.00
# Shae                              8.00     16.00     14.50      8.75
# Doreah                            9.50      3.00      0.00      0.00
# Selyse Baratheon                  0.00      0.25      2.00      5.25
# ...

# %%
# plt.figure()
# df.loc[['Jon Snow', 'Tywin Lannister'], 'season 1':'season 3'].plot(kind='bar')

df.sum(axis=1).sort_values(ascending=False)

df.loc[['Jon Snow', 'Tywin Lannister']].sum(axis=1).plot(kind='bar')
